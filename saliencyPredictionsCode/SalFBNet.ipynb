# %%
# !git clone https://github.com/gqding/SalFBNet.git

# %cd SalFBNet
# Out:
# Cloning into 'SalFBNet'...
# remote: Enumerating objects: 577, done.
# remote: Counting objects: 100% (419/419), done.
# remote: Compressing objects: 100% (257/257), done.
# remote: Total 577 (delta 189), reused 336 (delta 137), pack-reused 158 (from 1)
# Receiving objects: 100% (577/577), 18.58 MiB | 34.53 MiB/s, done.
# Resolving deltas: 100% (232/232), done.
# /content/SalFBNet

# %%
import os; os.getcwd()
# Out:
# '/content/SalFBNet'

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

zip_file_path = '/content/drive/MyDrive/Saliency4asd.zip'
extract_dir = 'Datasets/PseudoSaliency/'

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

print(f"Unzipped: {zip_file_path} to {extract_dir}")
# Out:
# Unzipped: /content/drive/MyDrive/Saliency4asd.zip to Datasets/PseudoSaliency/

# %%
#@title upload the model file

from google.colab import files

uploaded = files.upload()

for filename in uploaded.keys():
    with open(os.path.join('pretrained_models', filename), 'wb') as f:
        f.write(uploaded[filename])

print(f'File(s) uploaded to the "pretrained_models" folder: {list(uploaded.keys())}')

# %%
# !python main_test.py --model=pretrained_models/FBNet_Res18Fixed_best_model.pth \
 --save_fold=./results_Res18Fixed/ \
 --backbone=Res18Fixed\
 --test_path=Datasets/PseudoSaliency/Saliency4asd/Images/
# Out:
# FBNet
# FBNet(
#   (features): ResNet(
#     (conv1): Conv2d(3, 128, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
#@title download the salicency map obtained from SalFBNet model

from google.colab import files
import shutil
import os

temp_dir = 'temp_download'
os.makedirs(temp_dir, exist_ok=True)

# !zip -r "{temp_dir}/Val_PseudoSal.zip" "results_Res18Fixed/Val_PseudoSal"
shutil.move(f"{temp_dir}/Val_PseudoSal.zip", "SalFBNet.zip")

shutil.rmtree(temp_dir)

# Download the zip file
files.download('SalFBNet.zip')
# Out:
#   adding: results_Res18Fixed/Val_PseudoSal/ (stored 0%)
#   adding: results_Res18Fixed/Val_PseudoSal/298.png (deflated 20%)
#   adding: results_Res18Fixed/Val_PseudoSal/171.png (deflated 25%)
#   adding: results_Res18Fixed/Val_PseudoSal/117.png (deflated 23%)
#   adding: results_Res18Fixed/Val_PseudoSal/32.png (deflated 28%)
#   adding: results_Res18Fixed/Val_PseudoSal/82.png (deflated 28%)
#   adding: results_Res18Fixed/Val_PseudoSal/20.png (deflated 24%)
#   adding: results_Res18Fixed/Val_PseudoSal/83.png (deflated 28%)
#   adding: results_Res18Fixed/Val_PseudoSal/110.png (deflated 28%)
#   adding: results_Res18Fixed/Val_PseudoSal/129.png (deflated 29%)
#   adding: results_Res18Fixed/Val_PseudoSal/178.png (deflated 28%)
#   adding: results_Res18Fixed/Val_PseudoSal/85.png (deflated 26%)
#   adding: results_Res18Fixed/Val_PseudoSal/63.png (deflated 21%)
#   adding: results_Res18Fixed/Val_PseudoSal/187.png (deflated 22%)
# ...
